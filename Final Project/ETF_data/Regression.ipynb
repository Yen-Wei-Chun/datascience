# %% [markdown]
# # 回歸分析

# %% [markdown]
# 最後我們匯入整理好的股價與情緒分數的csv檔，進行回歸分析

# %%
SPY <- read.csv('reg_s_SPY.csv')
dim(SPY)
# Out:
# [1] 236   6

# %%
AGG <- read.csv('reg_s_AGG.csv')
UUP <- read.csv('reg_s_UUP.csv')
VNQ <- read.csv('reg_s_VNQ.csv')
GLD <- read.csv('reg_s_GLD.csv')

VDC <- read.csv('reg_s_VDC.csv')
VDE <- read.csv('reg_s_VDE.csv')
VFH <- read.csv('reg_s_VFH.csv')
VIS <- read.csv('reg_s_VIS.csv')
VAW <- read.csv('reg_s_VAW.csv')
VGT <- read.csv('reg_s_VGT.csv')
VOX <- read.csv('reg_s_VOX.csv')

# %%
# Price = α+β1(Score) +μ 
regg_SPY <- lm(SPY$Price ~ SPY$Score)
summary(regg_SPY)
# Out:
# Call:
# lm(formula = SPY$Price ~ SPY$Score)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -43.058  -5.961   1.941   8.932  16.681
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 2.773e+02  7.601e-01 364.830   <2e-16 ***
# SPY$Score   4.387e-03  2.065e-02   0.212    0.832
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 11.49 on 234 degrees of freedom
# Multiple R-squared:  0.0001927,	Adjusted R-squared:  -0.00408
# F-statistic: 0.04511 on 1 and 234 DF,  p-value: 0.832

# %% [markdown]
# 從以上的分析表得出β1接受虛無假設：β1 = 0，故SPY(Equity)的價格變動和情緒分數變動無顯著關係

# %%
# Price = α+β1(Score) +μ 
regg_AGG <- lm(AGG$Price ~ AGG$Score)
summary(regg_AGG)
# Out:
# Call:
# lm(formula = AGG$Price ~ AGG$Score)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.5440 -0.9453 -0.1568  0.8433  3.9349
#
# Coefficients:
#              Estimate Std. Error  t value Pr(>|t|)
# (Intercept) 1.065e+02  9.561e-02 1113.854   <2e-16 ***
# AGG$Score   1.038e-03  2.598e-03    0.399     0.69
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.446 on 234 degrees of freedom
# Multiple R-squared:  0.0006814,	Adjusted R-squared:  -0.003589
# F-statistic: 0.1595 on 1 and 234 DF,  p-value: 0.6899

# %% [markdown]
# 從以上的分析表得出β1接受虛無假設：β1 = 0，故AGG(Bond)的價格變動和情緒分數變動無顯著關係

# %%
# Price = α+β1(Score) +μ 
regg_UUP <- lm(UUP$Price ~ UUP$Score)
summary(regg_UUP)
# Out:
# Call:
# lm(formula = UUP$Price ~ UUP$Score)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.81198 -0.32592 -0.01684  0.27805  0.87856
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 2.557e+01  2.680e-02 953.901  < 2e-16 ***
# UUP$Score   2.763e-03  7.283e-04   3.794 0.000189 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4053 on 234 degrees of freedom
# Multiple R-squared:  0.05795,	Adjusted R-squared:  0.05393
# F-statistic:  14.4 on 1 and 234 DF,  p-value: 0.0001887

# %% [markdown]
# 從以上的分析表得出β1拒絕虛無假設：β1 = 0，故UUP(Currency)的價格變動和情緒分數變動有顯著關係，情緒分數每增加一分，價格變動0.002763，雖兩者顯著相關，但情緒分數對價格的影響非常小

# %%
# Price = α+β1(Score) +μ 
regg_VNQ <- lm(VNQ$Price ~ VNQ$Score)
summary(regg_VNQ)
# Out:
# Call:
# lm(formula = VNQ$Price ~ VNQ$Score)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -10.4854  -2.2499   0.2424   2.3400   6.2889
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 82.072920   0.233280 351.821   <2e-16 ***
# VNQ$Score    0.008968   0.006339   1.415    0.158
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.528 on 234 degrees of freedom
# Multiple R-squared:  0.008481,	Adjusted R-squared:  0.004244
# F-statistic: 2.002 on 1 and 234 DF,  p-value: 0.1585

# %% [markdown]
# 從以上的分析表得出β1接受虛無假設：β1 = 0，故VNQ(Real Estate)的價格變動和情緒分數變動無顯著關係

# %%
# Price = α+β1(Score) +μ 
regg_GLD <- lm(GLD$Price ~ GLD$Score)
summary(regg_GLD)
# Out:
# Call:
# lm(formula = GLD$Price ~ GLD$Score)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -7.4222 -3.1658  0.5336  3.0935  7.7520
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.185e+02  2.558e-01 463.412   <2e-16 ***
# GLD$Score   1.159e-02  6.949e-03   1.667   0.0968 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.868 on 234 degrees of freedom
# Multiple R-squared:  0.01174,	Adjusted R-squared:  0.007518
# F-statistic:  2.78 on 1 and 234 DF,  p-value: 0.09678

# %% [markdown]
# 從以上的分析表得出β1接受虛無假設：β1 = 0，故GLD(Commodity)的價格變動和情緒分數變動無顯著關係

# %%
# Price = α+β1(Score) +μ 
regg_VDC <- lm(VDC$Price ~ VDC$Score)
summary(regg_VDC)
# Out:
# Call:
# lm(formula = VDC$Price ~ VDC$Score)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -14.9030  -2.7574   0.2819   3.1986   9.7088
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.403e+02  2.941e-01 477.074  < 2e-16 ***
# VDC$Score   2.170e-02  7.992e-03   2.715  0.00711 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.448 on 234 degrees of freedom
# Multiple R-squared:  0.03055,	Adjusted R-squared:  0.0264
# F-statistic: 7.373 on 1 and 234 DF,  p-value: 0.007114

# %% [markdown]
# 從以上的分析表得出β1拒絕虛無假設：β1 = 0，故VDC(Consumer Staples)的價格變動和情緒分數變動有顯著關係，情緒分數每增加一分，價格變動0.0217，雖兩者顯著相關，但情緒分數對價格的影響非常小

# %%
# Price = α+β1(Score) +μ 
regg_VDE <- lm(VDE$Price ~ VDE$Score)
summary(regg_VDE)
# Out:
# Call:
# lm(formula = VDE$Price ~ VDE$Score)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -20.672  -5.817  -2.170   8.535  15.769
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 93.80441    0.57097 164.288  < 2e-16 ***
# VDE$Score   -0.05068    0.01551  -3.267  0.00125 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 8.634 on 234 degrees of freedom
# Multiple R-squared:  0.04361,	Adjusted R-squared:  0.03953
# F-statistic: 10.67 on 1 and 234 DF,  p-value: 0.001252

# %% [markdown]
# 從以上的分析表得出β1拒絕虛無假設：β1 = 0，故VDE(Energy)的價格變動和情緒分數變動有顯著關係，情緒分數每增加一分，價格變動-0.05068，雖兩者顯著相關，但情緒分數對價格的影響非常小

# %%
# Price = α+β1(Score) +μ 
regg_VFH <- lm(VFH$Price ~ VFH$Score)
summary(regg_VFH)
# Out:
# Call:
# lm(formula = VFH$Price ~ VFH$Score)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -11.265  -1.676   0.226   2.760   5.305
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 67.154604   0.224584 299.017   <2e-16 ***
# VFH$Score   -0.009357   0.006103  -1.533    0.127
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.396 on 234 degrees of freedom
# Multiple R-squared:  0.009948,	Adjusted R-squared:  0.005717
# F-statistic: 2.351 on 1 and 234 DF,  p-value: 0.1265

# %% [markdown]
# 從以上的分析表得出β1接受虛無假設：β1 = 0，故VFH(Financials)的價格變動和情緒分數變動無顯著關係

# %%
# Price = α+β1(Score) +μ 
regg_VIS <- lm(VIS$Price ~ VIS$Score)
summary(regg_VIS)
# Out:
# Call:
# lm(formula = VIS$Price ~ VIS$Score)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -25.399  -3.762   1.403   5.183  12.332
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 138.292533   0.505186   273.7   <2e-16 ***
# VIS$Score    -0.001371   0.013727    -0.1    0.921
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 7.639 on 234 degrees of freedom
# Multiple R-squared:  4.263e-05,	Adjusted R-squared:  -0.004231
# F-statistic: 0.009976 on 1 and 234 DF,  p-value: 0.9205

# %% [markdown]
# 從以上的分析表得出β1接受虛無假設：β1 = 0，故VIS(Industrials)的價格變動和情緒分數變動無顯著關係

# %%
# Price = α+β1(Score) +μ 
regg_VAW <- lm(VAW$Price ~ VAW$Score)
summary(regg_VAW)
# Out:
# Call:
# lm(formula = VAW$Price ~ VAW$Score)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -20.0160  -4.9442  -0.2482   6.8516  11.9842
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 124.67049    0.49899 249.845   <2e-16 ***
# VAW$Score    -0.03556    0.01356  -2.623   0.0093 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 7.546 on 234 degrees of freedom
# Multiple R-squared:  0.02855,	Adjusted R-squared:  0.0244
# F-statistic: 6.878 on 1 and 234 DF,  p-value: 0.009298

# %% [markdown]
# 從以上的分析表得出β1拒絕虛無假設：β1 = 0，故VAW(Materials)的價格變動和情緒分數變動有顯著關係，情緒分數每增加一分，價格變動-0.03556，雖兩者顯著相關，但情緒分數對價格的影響非常小

# %%
# Price = α+β1(Score) +μ 
regg_VGT <- lm(VGT$Price ~ VGT$Score)
summary(regg_VGT)
# Out:
# Call:
# lm(formula = VGT$Price ~ VGT$Score)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -35.593  -8.416   0.456   9.346  23.376
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 1.903e+02  8.089e-01 235.214   <2e-16 ***
# VGT$Score   8.098e-03  2.198e-02   0.368    0.713
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 12.23 on 234 degrees of freedom
# Multiple R-squared:  0.0005798,	Adjusted R-squared:  -0.003691
# F-statistic: 0.1357 on 1 and 234 DF,  p-value: 0.7129

# %% [markdown]
# 從以上的分析表得出β1接受虛無假設：β1 = 0，故VGT(Technology)的價格變動和情緒分數變動無顯著關係

# %%
# Price = α+β1(Score) +μ 
regg_VOX <- lm(VOX$Price ~ VOX$Score)
summary(regg_VOX)
# Out:
# Call:
# lm(formula = VOX$Price ~ VOX$Score)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -13.793  -2.229   1.042   2.842   6.238
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 83.56913    0.25356 329.583   <2e-16 ***
# VOX$Score   -0.01273    0.00689  -1.848   0.0658 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.834 on 234 degrees of freedom
# Multiple R-squared:  0.01439,	Adjusted R-squared:  0.01018
# F-statistic: 3.416 on 1 and 234 DF,  p-value: 0.06582

# %% [markdown]
# 從以上的分析表得出β1接受虛無假設：β1 = 0，故VOX(Telecom)的價格變動和情緒分數變動無顯著關係

# %% [markdown]
# # 回歸視覺化

# %%
par(mfrow = c(2,2))
plot(x = UUP$Score, y = UUP$Price, main='UUP', xlab = 'Score', ylab = 'Price')
abline(regg_UUP, col = "lightblue", lwd = 2)
plot(x = VDC$Score, y = VDC$Price, main='VDC', xlab = 'Score', ylab = 'Price')
abline(regg_VDC, col = "lightblue", lwd = 2)
plot(x = VDE$Score, y = VDE$Price, main='VDE', xlab = 'Score', ylab = 'Price')
abline(regg_VDE, col = "lightblue", lwd = 2)
plot(x = VAW$Score, y = VAW$Price, main='VAW', xlab = 'Score', ylab = 'Price')
abline(regg_VAW, col = "lightblue", lwd = 2)
# Out:
# Plot with title “VAW”
